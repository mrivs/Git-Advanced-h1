# %% [markdown]
# f(x) = -12x^4 - 18x^3+5x^2 + 10x - 30
#
# Определить корни
#
# Найти интервалы, на которых функция возрастает
#
# Найти интервалы, на которых функция убывает
#
# Построить график
#
# Вычислить вершину
#
# Определить промежутки, на котором f > 0
#
# Определить промежутки, на котором f < 0

# %% [markdown]
# 1) Установить:
#  pip install sympy
#  python.exe -m pip install --upgrade pip

# %%
import sympy
import numpy
import math
from sympy.plotting import plot

# %%
x=sympy.symbols("x")
y = -12*x**4 -18*x**3+5*x**2 +10*x-30

sol=([complex(i) for i in sympy.solve(y)])
print("Корни уравнения:")
for i in sol: print(f"{i:.4f}")
# Out:
# Корни уравнения:
# -1.4408+0.7273j
# 0.6908+0.6946j
# -1.4408-0.7273j
# 0.6908-0.6946j

# %%
dp=sympy.diff(y)
print (dp)
dpsol=([complex(i) for i in (sympy.solve(dp))])
print("Вершины:")
for i in dpsol: print(f"{i:.4f}")

print("промежутки, на котором функция возрастает:", sympy.solve(dp>0))
print("промежутки, на котором функция убывает:", sympy.solve(dp<0))
# Out:
# -48*x**3 - 54*x**2 + 10*x + 10
# Вершины:
# -0.4144+0.0000j
# -1.1484-0.0000j
# 0.4378-0.0000j
# промежутки, на котором функция возрастает: ((-oo < x) & (x < CRootOf(24*x**3 + 27*x**2 - 5*x - 5, 0))) | ((x < CRootOf(24*x**3 + 27*x**2 - 5*x - 5, 2)) & (CRootOf(24*x**3 + 27*x**2 - 5*x - 5, 1) < x))
# промежутки, на котором функция убывает: ((x < oo) & (CRootOf(24*x**3 + 27*x**2 - 5*x - 5, 2) < x)) | ((x < CRootOf(24*x**3 + 27*x**2 - 5*x - 5, 1)) & (CRootOf(24*x**3 + 27*x**2 - 5*x - 5, 0) < x))

# %%
print("промежутки, на котором f > 0:", sympy.solve(y>0))
print("промежутки, на котором f < 0:", sympy.solve(y<0))
# Out:
# промежутки, на котором f > 0: (x > -oo) & (x < oo) & Ne(x, 0)
# промежутки, на котором f < 0: False

# %%
plot(y,(x,-1.8,1))
plot(dp)
